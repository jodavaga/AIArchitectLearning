# %%
import sys
sys.path.insert(0, '/Users/jodavaga/Documents/Learning/ClaudeArchitect/prompt-validation')

# %%
from validation.generate_dataset import generate_dataset, write_json_file

dataset = generate_dataset()
write_json_file(dataset)
# Out:
# Answer: ```json
# [
#     {
#         "task": "Parse an AWS S3 bucket name and object key from an S3 URI in the format 's3://bucket-name/path/to/object'",
#         "format": "regex"
#     },
#     {
#         "task": "Create a Python function that validates an AWS IAM role ARN and returns True if valid, False otherwise",
#         "format": "python"
#     },
#     {
#         "task": "Generate a JSON CloudFormation template for creating an AWS S3 bucket with versioning enabled and public access blocked",
#         "format": "json"
#     }
# ]
# ```
# --- Generator
#
# [
#     {
#         "task": "Parse an AWS S3 bucket name and region from an S3 URI (s3://bucket-name/key) and return them as separate variables",
#         "format": "regex"
#     },
#     {
#         "task": "Create a JSON configuration object for an AWS Lambda function that includes function name, runtime, role ARN, timeout, and memory allocation",
#         "format": "json"
#     },
#     {
# ...

# %%
import json

from validation.data import dataset
from validation.evaluator_utils import run_evaluator

print( json.dumps(run_evaluator(dataset), indent=2) )
# Out:
# Average score: 6
# [
#   {
# ...
